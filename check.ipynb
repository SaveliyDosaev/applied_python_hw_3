# %%
import requests

response = requests.post(
    "http://localhost:8000/links/shorten",
    json={"original_url": "https://google.com"}
)
short_code = response.json()
response.json()
# Out:
# {'original_url': 'https://google.com',
#  'short_code': 'eCdg7C',
#  'created_at': '2025-04-01T17:17:59.248837',
#  'expires_at': None,
#  'click_count': 0,
#  'last_accessed': None,
#  'project': None}

# %%
import datetime
import requests

response = requests.post(
    "http://localhost:8000/links/shorten",
    json={"original_url": "https://google.com", "custom_alias": "hello", "expires_at": "2025-12-31T23:59:59"}
)
response.json()
# Out:
# {'detail': 'Alias already exists'}

# %%
url = f"http://localhost:8000/hello"
response = requests.get(url, allow_redirects=False)
response.headers['Location']
# Out:
# 'https://google.com'

# %%
url = f"http://localhost:8000/links/hello/stats"
response = requests.get(url)
response.json()
# Out:
# {'original_url': 'https://google.com',
#  'short_code': 'hello',
#  'created_at': '2025-04-01T17:15:49.746567',
#  'click_count': 1,
#  'last_accessed': '2025-04-01T17:17:59.279858'}

# %%
url = f"http://localhost:8000/links/hello"
response = requests.put(url, json={"original_url": "youtube.com"})
response.json()
# Out:
# {'original_url': 'youtube.com',
#  'short_code': 'hello',
#  'created_at': '2025-04-01T17:15:49.746567',
#  'expires_at': '2025-12-31T23:59:59',
#  'click_count': 1,
#  'last_accessed': '2025-04-01T17:17:59.279858',
#  'project': None}

# %%
url = f"http://localhost:8000/links/search"
response = requests.get(url, params={"original_url": "youtube.com"})
response.json()
# Out:
# [{'original_url': 'youtube.com',
#   'short_code': 'hello',
#   'created_at': '2025-04-01T17:02:01.338027',
#   'expires_at': '2025-12-31T23:59:59',
#   'click_count': 1}]

# %%
url = f"http://localhost:8000/links/hello"
response = requests.delete(url)
response.json()
# Out:
# {'message': 'Link deleted'}

# %%
response = requests.post(
    "http://localhost:8000/links/shorten",
    json={"original_url": "https://hse.ru", "project": "abra_cadabra"}
)
response = requests.post(
    "http://localhost:8000/links/shorten",
    json={"original_url": "https://vk.ru", "project": "abra_cadabra"}
)
response = requests.post(
    "http://localhost:8000/links/shorten",
    json={"original_url": "https://rutube.ru", "project": "abra_cadabra"}
)
url = f"http://localhost:8000/links/project/abra_cadabra"
response = requests.get(url)
response.json()
# Out:
# [{'original_url': 'https://hse.ru',
#   'short_code': '9QAhrj',
#   'created_at': '2025-04-01T17:21:06.384878',
#   'expires_at': None,
#   'click_count': 0,
#   'last_accessed': None,
#   'project': 'abra_cadabra'},
#  {'original_url': 'https://vk.ru',
#   'short_code': 'zEMERK',
#   'created_at': '2025-04-01T17:21:06.391215',
#   'expires_at': None,
#   'click_count': 0,
#   'last_accessed': None,
#   'project': 'abra_cadabra'},
#  {'original_url': 'https://rutube.ru',
#   'short_code': 'WKSJm4',
#   'created_at': '2025-04-01T17:21:06.396708',
#   'expires_at': None,
#   'click_count': 0,
#   'last_accessed': None,
#   'project': 'abra_cadabra'}]
